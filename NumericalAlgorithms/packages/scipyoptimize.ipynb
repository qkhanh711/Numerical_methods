# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import scipy.optimize as opt
import numpy as np
import matplotlib.pyplot as plt

def func_x(x):
    return - x**5 - 2*x + 1

x = np.arange(-10, 10, 0.1)
plt.plot(x, func_x(x))

# %% [markdown]
# # Single-variable function

# %%
# %%time
Newton_Raphson = opt.newton(func_x, x0=0.1)
print("Newton_Raphson: ", Newton_Raphson)
# Out:
# Newton_Raphson:  0.4863890359345082
# CPU times: user 540 µs, sys: 0 ns, total: 540 µs
# Wall time: 546 µs

# %%
# %%time
Brent = opt.brentq(func_x, a=-10, b=10)
print("Brent: ", Brent)
# Out:
# Brent:  0.48638903593454297
# CPU times: user 255 µs, sys: 0 ns, total: 255 µs
# Wall time: 243 µs

# %%
# %%time
Bisect = opt.bisect(func_x, a=-10, b=10)
print("Bisect: ", Bisect)
# Out:
# Bisect:  0.48638903593541727
# CPU times: user 261 µs, sys: 23 µs, total: 284 µs
# Wall time: 289 µs

# %% [markdown]
# # Multi-variable function

# %%
def func_xy(x, y):
    return x**3 + (x)**2 + (y) - 4

x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)

X, Y = np.meshgrid(x, y)
Z = func_xy(X, Y)  

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.contour(X, Y, Z, levels=[0])
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_aspect('equal')
ax.grid(True)

# %%
# %%time
Newton_Raphson = opt.newton(func_xy, x0=0.1, args=(0.1,))
print("Newton_Raphson: ", Newton_Raphson)
# Out:
# Newton_Raphson:  1.301693083330381
# CPU times: user 997 µs, sys: 39 µs, total: 1.04 ms
# Wall time: 1.04 ms

# %%
# %%time
Brent = opt.brentq(func_xy, a=-10, b=10, args=(0.1,))
print("Brent: ", Brent)
# Out:
# Brent:  1.3016930833302733
# CPU times: user 223 µs, sys: 8 µs, total: 231 µs
# Wall time: 228 µs

# %%
# %%time
Bisect = opt.bisect(func_xy, a=-10, b=10, args=(0.1,))
print("Bisect: ", Bisect)
# Out:
# Bisect:  1.3016930833293827
# CPU times: user 179 µs, sys: 0 ns, total: 179 µs
# Wall time: 182 µs

# %%
def func_xy(x, y):
    return x**2 + y**2 - 2

x = np.arange(-10, 10, 0.1)
y = np.arange(-10, 10, 0.1)

X, Y = np.meshgrid(x, y)
Z = func_xy(X, Y)

# 3D plot
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='jet')
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
# ax.set_aspect('equal')
ax.grid(True)
